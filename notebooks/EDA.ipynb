# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Data Preprocessing

# %%
movies = pd.read_csv('../data/movies.csv')
credits = pd.read_csv(r"D:\project\credits.csv") # since credits.csv is large so it is not in github so i have imported from my computer

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %% [markdown]
# 👆 id is TMDB id

# %%
credits.head(1)
# Out:
#    movie_id   title                                               cast  \
# 0     19995  Avatar  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %% [markdown]
# ### we will merge both datframes into single dataframe
# based on title since it common in both datsets

# %%
df = movies.merge(credits, on = 'title')

# %%
df.shape
# Out:
# (4809, 23)

# %%
df.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ... runtime  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                        tagline   title vote_average vote_count movie_id  \
# 0  Enter the World of Pandora.  Avatar          7.2      11800    19995
#
# ...

# %% [markdown]
# ## To make content based movie recommender system
# 1. collect important column to create tags
#     * high budget does not mean good movie necessarily
#     * - [ ] genres
#     * - [ ] id
#     * - [ ] keywords
#     * - [ ] title
#     * - [ ] overview
#     * language does not really matters
#     * - [ ] cast
#     * - [ ] crew

# %%
df['original_language'].value_counts()
# Out:
# original_language
# en    4510
# fr      70
# es      32
# zh      27
# de      27
# hi      19
# ja      16
# it      14
# ko      12
# cn      12
# ru      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# ta       2
# cs       2
# ro       2
# id       2
# ar       2
# vi       1
# sl       1
# ps       1
# no       1
# ky       1
# hu       1
# pl       1
# af       1
# nb       1
# tr       1
# is       1
# xx       1
# te       1
# el       1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4809 non-null   int64
#  1   genres                4809 non-null   object
#  2   homepage              1713 non-null   object
#  3   id                    4809 non-null   int64
#  4   keywords              4809 non-null   object
#  5   original_language     4809 non-null   object
#  6   original_title        4809 non-null   object
#  7   overview              4806 non-null   object
#  8   popularity            4809 non-null   float64
#  9   production_companies  4809 non-null   object
#  10  production_countries  4809 non-null   object
#  11  release_date          4808 non-null   object
#  12  revenue               4809 non-null   int64
#  13  runtime               4807 non-null   float64
#  14  spoken_languages      4809 non-null   object
# ...

# %%
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %% [markdown]
# ## we will work on following features

# %%
features = ['title','id', 'genres', 'overview', 'keywords', 'cast', 'crew']

# %%
df = df[features]

# %%
df.head()
# Out:
#                                       title      id  \
# 0                                    Avatar   19995
# 1  Pirates of the Caribbean: At World's End     285
# 2                                   Spectre  206647
# 3                     The Dark Knight Rises   49026
# 4                               John Carter   49529
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
# ...

# %%
# lets chek null values
df.isnull().sum()
# Out:
# title       0
# id          0
# genres      0
# overview    3
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %% [markdown]
# 👆 3 overview is null lets remove

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# title       0
# id          0
# genres      0
# overview    0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
# lets check for duplicate data
df.duplicated().sum()
# Out:
# 0

# %%
df.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %% [markdown]
# Importing the 'convert' function from the 'data_preprocessing' module
# Applying the 'convert' function to the 'genres' column of the DataFrame 'df'
# The `apply` method is used to apply the 'convert' function to each element in the 'genres' column.
# This will transform each string representation of a list of dictionaries in the 'genres' column
# into a list of names, which will then be assigned back to the 'genres' column of the DataFrame.

# %%
import sys
import os

# Add the src folder to the system path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

from data_preprocessing import convert

df.genres = df['genres'].apply(convert)

# %%
df.genres
# Out:
# 0       [Action, Adventure, Fantasy, Science Fiction]
# 1                        [Adventure, Fantasy, Action]
# 2                          [Action, Adventure, Crime]
# 3                    [Action, Crime, Drama, Thriller]
# 4                [Action, Adventure, Science Fiction]
#                             ...
# 4804                        [Action, Crime, Thriller]
# 4805                                [Comedy, Romance]
# 4806               [Comedy, Drama, Romance, TV Movie]
# 4807                                               []
# 4808                                    [Documentary]
# Name: genres, Length: 4806, dtype: object

# %% [markdown]
# We  will do same with `keywords` column

# %%
import sys
import os

# Add the src folder to the system path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

from data_preprocessing import convert

df.keywords = df['keywords'].apply(convert)

# %%
df.keywords.head()
# Out:
# 0    [culture clash, future, space war, space colon...
# 1    [ocean, drug abuse, exotic island, east india ...
# 2    [spy, based on novel, secret agent, sequel, mi...
# 3    [dc comics, crime fighter, terrorist, secret i...
# 4    [based on novel, mars, medallion, space travel...
# Name: keywords, dtype: object

# %% [markdown]
# ## same thing will do with `cast` this time need only 3 name of casts

# %%
df.cast[0][1:1000]
# Out:
# '{"cast_id": 242, "character": "Jake Sully", "credit_id": "5602a8a7c3a3685532001c9a", "gender": 2, "id": 65731, "name": "Sam Worthington", "order": 0}, {"cast_id": 3, "character": "Neytiri", "credit_id": "52fe48009251416c750ac9cb", "gender": 1, "id": 8691, "name": "Zoe Saldana", "order": 1}, {"cast_id": 25, "character": "Dr. Grace Augustine", "credit_id": "52fe48009251416c750aca39", "gender": 1, "id": 10205, "name": "Sigourney Weaver", "order": 2}, {"cast_id": 4, "character": "Col. Quaritch", "credit_id": "52fe48009251416c750ac9cf", "gender": 2, "id": 32747, "name": "Stephen Lang", "order": 3}, {"cast_id": 5, "character": "Trudy Chacon", "credit_id": "52fe48009251416c750ac9d3", "gender": 1, "id": 17647, "name": "Michelle Rodriguez", "order": 4}, {"cast_id": 8, "character": "Selfridge", "credit_id": "52fe48009251416c750ac9e1", "gender": 2, "id": 1771, "name": "Giovanni Ribisi", "order": 5}, {"cast_id": 7, "character": "Norm Spellman", "credit_id": "52fe48009251416c750ac9dd", "gender":
# ...

# %%
import sys
import os

# Add the src folder to the system path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

from data_preprocessing import convert_cast

# %%
df['cast'] = df['cast'].apply(convert_cast)

# %%
df.head()
# Out:
#                                       title      id  \
# 0                                    Avatar   19995
# 1  Pirates of the Caribbean: At World's End     285
# 2                                   Spectre  206647
# 3                     The Dark Knight Rises   49026
# 4                               John Carter   49529
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
# ...

# %%
df.crew[0] # we can see what is in crew column's first element

# %%
import sys
import os

# Add the src folder to the system path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

from data_preprocessing import fetch_director

# %%
df['crew'] = df['crew'].apply(fetch_director)

# %%
df['crew']
# Out:
# 0           [James Cameron]
# 1          [Gore Verbinski]
# 2              [Sam Mendes]
# 3       [Christopher Nolan]
# 4          [Andrew Stanton]
#                ...
# 4804     [Robert Rodriguez]
# 4805         [Edward Burns]
# 4806          [Scott Smith]
# 4807          [Daniel Hsia]
# 4808     [Brian Herzlinger]
# Name: crew, Length: 4806, dtype: object

# %%
df.overview[0]
# Out:
# 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.'

# %% [markdown]
# 👆 we can see overview column is in string format. let's convert this to list.\ will do using `lambda` and `split` function

# %%
df['overview'] = df['overview'].apply(lambda x: x.split())

# %%
df.head()
# Out:
#                                       title      id  \
# 0                                    Avatar   19995
# 1  Pirates of the Caribbean: At World's End     285
# 2                                   Spectre  206647
# 3                     The Dark Knight Rises   49026
# 4                               John Carter   49529
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
# ...

# %% [markdown]
# #### we will merge words of single name or genres
# #### like science fiction to sciencefiction

# %%
df['genres'] = df['genres'].apply(lambda gen : [item.replace(" ", "") for item in gen])

# %% [markdown]
# ### same thing for `crew`, `cast`, `keywords`

# %%
df['cast'] = df['cast'].apply(lambda c : [item.replace(" ", "") for item in c])
df['crew'] = df['crew'].apply(lambda c : [item.replace(" ", "") for item in c])
df['keywords'] = df['keywords'].apply(lambda k : [item.replace(" ", "") for item in k])

# %%
df.head()
# Out:
#                                       title      id  \
# 0                                    Avatar   19995
# 1  Pirates of the Caribbean: At World's End     285
# 2                                   Spectre  206647
# 3                     The Dark Knight Rises   49026
# 4                               John Carter   49529
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
# ...

# %% [markdown]
# ## now we will merge all the columns except title and movie_id to a column named tags to create tags for recommender system

# %%
df['tags'] = df['cast'] + df['keywords'] + df['crew'] + df['genres']

# %%
df.head()
# Out:
#                                       title      id  \
# 0                                    Avatar   19995
# 1  Pirates of the Caribbean: At World's End     285
# 2                                   Spectre  206647
# 3                     The Dark Knight Rises   49026
# 4                               John Carter   49529
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
# ...

# %% [markdown]
# ### lets create new dataframe of `id`, `title`, `tags`.

# %%
new_df = df[['id', 'title', 'tags']]

# %%
new_df.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 tags
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver, ...
# 1  [JohnnyDepp, OrlandoBloom, KeiraKnightley, oce...
# 2  [DanielCraig, ChristophWaltz, LéaSeydoux, spy,...
# 3  [ChristianBale, MichaelCaine, GaryOldman, dcco...
# 4  [TaylorKitsch, LynnCollins, SamanthaMorton, ba...
